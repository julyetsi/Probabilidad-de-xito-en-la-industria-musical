# %% [markdown]
# # NOTEBOOK 1

# %% [markdown]
# ### - En este notebook encontraremos los csvs importados con pandas junto con sus datos básicos y algunas visualizaciones para entenderlo mejor.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # ***SPOTIFY DATA***
# ### Our columns here:
# - name - Name of song
# - album - Name of album
# - artist - Name of artist/s involved
# - release_date - Release date of album
# - length - Song length in milliseconds
# - popularity - Percent popularity of the song based on Spotify's algorithm (possibly the number of stream at a certain period of time)
# - danceability - How suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity
# - acousticness - How acoustic a song is
# - energy - A perceptual measure of intensity and activity
# - instrumentalness - Te amount of vocals in the song
# - liveness - Probability that the song was recorded with a live audience
# - loudness - Tdency o of music to be recorded at steadily higher volumes
# - speechiness - Presence of spoken words in a track (if the speechiness of a song is above 0.66, it is probably made of spoken words, a score between 0.33 and 0.66 is a song that may contain both music and words, and a score below 0.33 means the song does not have any speech)
# - valence - A measure of how happy or sad the song sounds
# - tempo - Beats per minute

# %%
spotart= pd.read_csv('Data/artists.csv')

# %%
spotart.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
spotart.describe()
# Out:
#           followers    popularity
# count  1.104336e+06  1.104349e+06
# mean   1.074304e+04  9.083884e+00
# std    2.609554e+05  1.376310e+01
# min    0.000000e+00  0.000000e+00
# 25%    1.000000e+01  0.000000e+00
# 50%    5.900000e+01  2.000000e+00
# 75%    4.510000e+02  1.400000e+01
# max    7.890023e+07  1.000000e+02

# %%
spotart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104349 entries, 0 to 1104348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1104349 non-null  object
#  1   followers   1104336 non-null  float64
#  2   genres      1104349 non-null  object
#  3   name        1104346 non-null  object
#  4   popularity  1104349 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 42.1+ MB

# %%
spotart.columns
# Out:
# Index(['id', 'followers', 'genres', 'name', 'popularity'], dtype='object')

# %%
spotart.shape
# Out:
# (1104349, 5)

# %%
# Histogramas para las métricas de Spotify
#plt.figure(figsize=(15, 10))

#plt.subplot(2, 2, 1)
#sns.histplot(spotart['popularity'], bins=30, kde=True, color='lightcoral')
#plt.title('Distribución de Popularidad en Spotify')

#plt.subplot(2, 2, 2)
#sns.histplot(spotart['followers'], bins=30, kde=True, color='lightcoral')
#plt.title('Distribución de Danceability en Spotify')

#plt.subplot(2, 2, 3)
#sns.histplot(spotart['name'], bins=30, kde=True, color='lightcoral')
#plt.title('Distribución de Energy en Spotify')


#plt.tight_layout()
#plt.show()

# %% [markdown]
# # ***tracks.csv***

# %%
spotracks = pd.read_csv('Data/tracks.csv')

# %%
spotracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
spotracks.shape
# Out:
# (586672, 20)

# %%
spotracks.describe()
# Out:
#           popularity   duration_ms       explicit   danceability  \
# count  586672.000000  5.866720e+05  586672.000000  586672.000000
# mean       27.570053  2.300512e+05       0.044086       0.563594
# std        18.370642  1.265261e+05       0.205286       0.166103
# min         0.000000  3.344000e+03       0.000000       0.000000
# 25%        13.000000  1.750930e+05       0.000000       0.453000
# 50%        27.000000  2.148930e+05       0.000000       0.577000
# 75%        41.000000  2.638670e+05       0.000000       0.686000
# max       100.000000  5.621218e+06       1.000000       0.991000
#
#               energy            key       loudness           mode  \
# count  586672.000000  586672.000000  586672.000000  586672.000000
# mean        0.542036       5.221603     -10.206067       0.658797
# std         0.251923       3.519423       5.089328       0.474114
# min         0.000000       0.000000     -60.000000       0.000000
# ...

# %%
spotracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
spotracks.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
# Histograms for YouTube metrics
plt.figure(figsize=(15, 10))
#kde para suavizar la lectura
# viewCount
plt.subplot(2, 2, 1)
sns.histplot(spotracks['popularity'], bins=30, kde=True, color='lightgreen')
plt.title('Popularidad')

# likeCount
plt.subplot(2, 2, 2)
sns.histplot(spotracks['danceability'], bins=30, kde=True, color='lightgreen')
plt.title('Danceability')

# dislikeCount
plt.subplot(2, 2, 3)
sns.histplot(spotracks['key'], bins=10, kde=True, color='lightgreen')
plt.title('Tonalidad')

# commentCount
plt.subplot(2, 2, 4)
sns.histplot(spotracks['tempo'], bins=30, kde=True, color='lightgreen')
plt.title('Tempo')

plt.tight_layout()
plt.show()

# %%
# Correlation Matrix
plt.figure(figsize=(10, 8))
correlation_matrix = spotracks[['popularity', 'danceability', 'tempo', 'key']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Between Metrics')
plt.show()

# %% [markdown]
# ## primeras limpiezas

# %%
spotracks.head(2)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
#
#    duration_ms  explicit              artists               id_artists  \
# 0       126903         0              ['Uli']  [45tIt06XoI0Iio4LBEVpls
# 1        98200         0  ['Fernando Pessoa']  [14jtPCOoNZwquk5wd9DxrY
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645   0.445    0   -13.338     1        0.451
# 1   1922-06-01         0.695   0.263    0   -22.136     1        0.957
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674             0.744     0.151    0.127  104.851               3
# 1         0.797             0.000     0.148    0.655  102.009               1

# %%
# En la colnmna id_artists e artist hay strings entre corchetes y lo queremos eliminar.
spotracks['id_artists'] = spotracks['id_artists'].str.replace("\['", "").str.replace("\']","").str.replace("'","")

# %%
track_df = spotracks

# %%
track_df['id_artists'] = track_df['id_artists'].apply(lambda x: x[1:] if pd.notnull(x) else x)

# %%
track_df.head(2)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
#
#    duration_ms  explicit              artists              id_artists  \
# 0       126903         0              ['Uli']  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  ['Fernando Pessoa']  14jtPCOoNZwquk5wd9DxrY
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645   0.445    0   -13.338     1        0.451
# 1   1922-06-01         0.695   0.263    0   -22.136     1        0.957
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674             0.744     0.151    0.127  104.851               3
# 1         0.797             0.000     0.148    0.655  102.009               1

# %%
track_df['artists'] = track_df['artists'].str.replace("\['", "").str.replace("\']","").str.replace("'","")

# %%
track_df.head(2)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
#
#    duration_ms  explicit           artists              id_artists  \
# 0       126903         0              [Uli  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  [Fernando Pessoa  14jtPCOoNZwquk5wd9DxrY
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645   0.445    0   -13.338     1        0.451
# 1   1922-06-01         0.695   0.263    0   -22.136     1        0.957
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674             0.744     0.151    0.127  104.851               3
# 1         0.797             0.000     0.148    0.655  102.009               1

# %%
track_df['artists'] = track_df['artists'].apply(lambda x: x[1:] if pd.notnull(x) else x)

# %%
track_df.head() #ready con los ['']
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit          artists              id_artists  \
# 0       126903         0              Uli  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  Fernando Pessoa  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
track_df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
#Eliminemos columnas
#track_df.drop(columns=['explicit', 'release_date', 'loudness', 'mode', 'time_signature'], inplace=True)

# %%
track_df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'artists', 'id_artists',
#        'danceability', 'energy', 'key', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
track_df.shape
# Out:
# (586672, 15)

# %% [markdown]
# ### El otro dataset

# %%
df_art = spotart
df_art.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
#df_art.drop(columns=['followers', 'popularity'], inplace=True)

# %%
df_art.head(2)
# Out:
#                        id genres  \
# 0  0DheY5irMjBUeLybbCUEZ2     []
# 1  0DlhY15l3wsrnlfGio2bjU     []
#
#                                              name
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani
# 1                                     ปูนา ภาวิณี

# %%
df = df_art[df_art['genres'] != '[]']
df.head() # eliminamos los registros en los que el valor de la variable genre sea = []
# Out:
#                          id                      genres  \
# 45   0VLMVnVbJyJ4oyZs2L3Yl2          ['carnaval cadiz']
# 46   0dt23bs4w8zx154C5xdVyl          ['carnaval cadiz']
# 47   0pGhoB99qpEJEsBQxgaskQ          ['carnaval cadiz']
# 48   3HDrX2OtSuXLW5dLR85uN3          ['carnaval cadiz']
# 136  22mLrN5fkppmuUPsHx6i2G  ['classical harp', 'harp']
#
#                              name
# 45   Las Viudas De Los Bisabuelos
# 46              Los De Capuchinos
# 47             Los “Pofesionales”
# 48      Los Que No Paran De Rajar
# 136                   Vera Dulova

# %%
#df['genres'] = df['genres'].apply(lambda x: x[1:-1] if pd.notnull(x) else x)

#eliminemos los corchetes de las columna genres

# IMPORTANTE: para quitar también las ' ', he vuelto a ejecutar esta linea de código y la he comentado para que no haga más desastricos
# Out:
# /var/folders/k1/r149v1_s4zd2tvc0m1c4cqcr0000gn/T/ipykernel_33492/4024391919.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['genres'].apply(lambda x: x[1:-1] if pd.notnull(x) else x)

# %%
df.head()
# Out:
#                          id                  genres  \
# 45   0VLMVnVbJyJ4oyZs2L3Yl2          carnaval cadiz
# 46   0dt23bs4w8zx154C5xdVyl          carnaval cadiz
# 47   0pGhoB99qpEJEsBQxgaskQ          carnaval cadiz
# 48   3HDrX2OtSuXLW5dLR85uN3          carnaval cadiz
# 136  22mLrN5fkppmuUPsHx6i2G  classical harp', 'harp
#
#                              name
# 45   Las Viudas De Los Bisabuelos
# 46              Los De Capuchinos
# 47             Los “Pofesionales”
# 48      Los Que No Paran De Rajar
# 136                   Vera Dulova

# %%
df.shape # Hemos pasado de más de un millón de registros, a casi 300k... a ver qué queda con el merge
# Out:
# (298616, 3)

# %% [markdown]
# -----------
# -----------
# -----------
#
#
# # **MERGE**
#
#
# ------------
# ------------
# ------------

# %% [markdown]
# Haremos la mezcla de los datasets a partir de la columna id (que será el id de los tracks). Para esto, lo primero será asegurarnos de que ningún id tiene menos de 22 caracteres.

# %%
df[df['id'].str.len().sort_values(ascending=False).apply(lambda x: x < 22)]
# Out:
# /var/folders/k1/r149v1_s4zd2tvc0m1c4cqcr0000gn/T/ipykernel_33492/1537156620.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['id'].str.len().sort_values(ascending=False).apply(lambda x: x < 22)]
# Empty DataFrame
# Columns: [id, genres, name]
# Index: []

# %%
track_df[track_df['id'].str.len().sort_values(ascending=False).apply(lambda x: x < 22)]
# Out:
# /var/folders/k1/r149v1_s4zd2tvc0m1c4cqcr0000gn/T/ipykernel_33492/3338795822.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   track_df[track_df['id'].str.len().sort_values(ascending=False).apply(lambda x: x < 22)]
# Empty DataFrame
# Columns: [id, name, popularity, duration_ms, artists, id_artists, danceability, energy, key, speechiness, acousticness, instrumentalness, liveness, valence, tempo]
# Index: []

# %%
cols_artists = ['id', 'genres']
merged = track_df.merge(df[cols_artists], how='left', left_on='id_artists', right_on='id', validate='many_to_one')
merged
# Out:
#                           id_x                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms                    artists  \
# 0                6       126903                        Uli
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_x              586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   artists           586672 non-null  object
#  5   id_artists        586672 non-null  object
#  6   danceability      586672 non-null  float64
#  7   energy            586672 non-null  float64
#  8   key               586672 non-null  int64
#  9   speechiness       586672 non-null  float64
#  10  acousticness      586672 non-null  float64
#  11  instrumentalness  586672 non-null  float64
#  12  liveness          586672 non-null  float64
#  13  valence           586672 non-null  float64
#  14  tempo             586672 non-null  float64
# ...

# %%
merged = merged.dropna()

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 432162 entries, 2 to 586671
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_x              432162 non-null  object
#  1   name              432162 non-null  object
#  2   popularity        432162 non-null  int64
#  3   duration_ms       432162 non-null  int64
#  4   artists           432162 non-null  object
#  5   id_artists        432162 non-null  object
#  6   danceability      432162 non-null  float64
#  7   energy            432162 non-null  float64
#  8   key               432162 non-null  int64
#  9   speechiness       432162 non-null  float64
#  10  acousticness      432162 non-null  float64
#  11  instrumentalness  432162 non-null  float64
#  12  liveness          432162 non-null  float64
#  13  valence           432162 non-null  float64
#  14  tempo             432162 non-null  float64
#  15  id_y              432162 non-null  object
# ...

# %%
unique_genres = merged['genres'].unique()
print(unique_genres)
# Out:
# ["tango', 'vintage tango"
#  "adult standards', 'big band', 'easy listening', 'lounge', 'swing"
#  'vintage chanson' ... "anthem worship', 'deep ccm', 'world worship"
#  "anthem worship', 'roots worship"
#  "alt z', 'alternative r&b', 'bedroom pop', 'indie cafe pop', 'indie pop', 'pop"]

# %%
num_unique_genres = merged['genres'].nunique()
print(num_unique_genres)
# Out:
# 18513

# %%
top_genres = merged['genres'].value_counts().head(100)
print(top_genres)
# Out:
# genres
# hoerspiel                                                                                                                8027
# kleine hoerspiel                                                                                                         2081
# classic italian pop', 'italian adult pop                                                                                 1781
# classic israeli pop', 'israeli rock                                                                                      1725
# adult standards', 'easy listening', 'lounge                                                                              1529
#                                                                                                                          ...
# adult standards', 'dixieland', 'harlem renaissance', 'jazz trumpet', 'new orleans jazz', 'soul', 'swing', 'vocal jazz     410
# ...

# %%
top_genres.iloc[:20]
# Out:
# genres
# hoerspiel                                                              8027
# kleine hoerspiel                                                       2081
# classic italian pop', 'italian adult pop                               1781
# classic israeli pop', 'israeli rock                                    1725
# adult standards', 'easy listening', 'lounge                            1529
# tango', 'vintage tango                                                 1486
# classic bollywood', 'desi pop', 'filmi', 'sufi                         1385
# c-pop', 'cantopop', 'classic cantopop                                  1199
# greek pop', 'laiko                                                     1197
# classic israeli pop                                                    1180
# classic icelandic pop', 'icelandic pop', 'icelandic rock               1133
# vintage taiwan pop                                                     1097
# ...

# %% [markdown]
# #### Hemos visto que luego de eliminar los valores "nulos" en la columna genres aún hay mas de 18.000 géneros. Escogemos los 100 que más se repiten y manualmente vamos viendo cuáles son los géneros que más nos interesan para aproximar nuestro dataframe a lo que más me interesa.

# %%
'latin pop', "pop romantico", 'dance pop', 'pop', 'country rock', 'folk', 
'singer-songwriter', 'easy listening', 'rock', 'soft rock', 'jazz blues', 
'lounge', 'soul' #Muy bien. Lo que quiero hacer es quedarme solo con los registros 
#de mi data frame "merged" que coincidan en su columna genero con los generos que me interesan.

# %%
columnas_especificas = merged[['genres']]
columnas_especificas.head(20)
# Out:
#                                                genres
# 2                              tango', 'vintage tango
# 3                              tango', 'vintage tango
# 4   adult standards', 'big band', 'easy listening'...
# 5   adult standards', 'big band', 'easy listening'...
# 7                                     vintage chanson
# 9                              tango', 'vintage tango
# 14                                    vintage chanson
# 19                             tango', 'vintage tango
# 22                             tango', 'vintage tango
# 26                                    vintage chanson
# 27                             tango', 'vintage tango
# 28                                    vintage chanson
# 30                                    vintage chanson
# 31                             tango', 'vintage tango
# 32  adult standards', 'big band', 'easy listening'...
# 33                             tango', 'vintage tango
# ...

# %%
# Un nuevo data frame por si meto la patota
nuevo_merged = merged.copy()

# Limpiamos  la columna 'genres', seleccionando solo elprimer elemento (en caso de que hayan más de 1) y quitando las comillas
nuevo_merged['genres'] = nuevo_merged['genres'].apply(lambda x: x.split(",")[0].strip("'"))
nuevo_merged['genres'].head(20)
# Out:
# 2               tango
# 3               tango
# 4     adult standards
# 5     adult standards
# 7     vintage chanson
# 9               tango
# 14    vintage chanson
# 19              tango
# 22              tango
# 26    vintage chanson
# 27              tango
# 28    vintage chanson
# 30    vintage chanson
# 31              tango
# 32    adult standards
# 33              tango
# 34              tango
# 38              tango
# 39            cabaret
# 41              tango
# Name: genres, dtype: object

# %%
nuevo_merged.head()
# Out:
#                      id_x                                name  popularity  \
# 2  07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                 Lady of the Evening           0
# 5  0BRXJHRNGQ3W4v9frnSfhu                           Ave Maria           0
# 7  0IA0Hju8CAgYfV1hwhidBH                             La Java           0
#
#    duration_ms          artists              id_artists  danceability  energy  \
# 2       181640  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2         0.434  0.1770
# 3       176907  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2         0.321  0.0946
# 4       163080      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su         0.402  0.1580
# 5       178933      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su         0.227  0.2610
# 7       161427      Mistinguett  4AxgXfD7ISvJSTObqm4aIE         0.563  0.1840
#
# ...

# %% [markdown]
# # cool :D
#
# ### Ahora queremos quedarnos con las canciones pertenecientes a los géneros que habíamos seleccionado antes.

# %%
# Una lista para los generos que quiero
mis_genres = ['latin pop', 'pop romantico', 'dance pop', 'pop', 'country rock', 'folk',
                      'singer-songwriter', 'easy listening', 'rock', 'soft rock', 'jazz blues',
                      'lounge', 'soul']

# %%
#Filtramos
nuevo_merged_filtrado = nuevo_merged[nuevo_merged['genres'].isin(mis_genres)]

# %%
nuevo_merged_filtrado.tail()
# Out:
#                          id_x                            name  popularity  \
# 7283   26VPiy1V7zJGGbxJ0BQ99E                Bandstand Boogie          19
# 18917  0X0os5JWXl3gZBJBGPsZod              Blues-Opera Act II           0
# 19112  1YyJznATh26J71SeViR0LU               Blues-Opera Act I           0
# 19134  1dVYS3Ba01EtkDgfunQzcq               Out Of This World           0
# 19403  2r5IiwxvPWl5czcxHKZB2e  Stormy Weather - 78rpm Version           0
#
#        duration_ms                            artists              id_artists  \
# 7283        120893                         Les Elgart  5Shuh8SGRGv8smsRPyM01R
# 18917       722760  Andre Kostelanetz & His Orchestra  0O834tNw0PiiuYgj24yq0b
# 19112       848667  Andre Kostelanetz & His Orchestra  0O834tNw0PiiuYgj24yq0b
# 19134       309827  Andre Kostelanetz & His Orchestra  0O834tNw0PiiuYgj24yq0b
# 19403       251160  Andre Kostelanetz & His Orchestra  0O834tNw0PiiuYgj24yq0b
#
# ...

# %%
nuevo_merged_filtrado.shape #muy bien, me he quedado con casi 9.000 tracks, con eso puedo trabajar.
# Out:
# (8995, 17)
